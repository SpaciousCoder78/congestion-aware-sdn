# %% [raw]
# Creating a Test Network Situation using NetworkX

# %%
pip install networkx matplotlib numpy torch gymnasium
# Out:
# Requirement already satisfied: networkx in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (3.6.1)
# Requirement already satisfied: matplotlib in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (3.10.8)
# Requirement already satisfied: numpy in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (2.4.2)
# Requirement already satisfied: torch in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (2.10.0)
# Collecting gymnasium
#   Downloading gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: filelock in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from torch) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from torch) (82.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from torch) (1.14.0)
# Requirement already satisfied: jinja2 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from torch) (2026.2.0)
# Collecting cloudpickle>=1.2.0 (from gymnasium)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.5/libexec/lib/python3.14/site-packages (from jinja2->torch) (3.0.3)
# Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 18.6 MB/s  0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, cloudpickle, gymnasium
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [gymnasium]
# Successfully installed cloudpickle-3.1.2 farama-notifications-0.0.4 gymnasium-1.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np


Graph = nx.waxman_graph(10, beta=0.4, alpha=0.1)

Graph.add_edge(0,1)
Graph.add_edge(0,4)
Graph.add_edge(1,5)
Graph.add_edge(2,5)
Graph.add_edge(6,8)
Graph.add_edge(7,9)
Graph.add_edge(9,3)
Graph.add_edge(8,4)
Graph.add_edge(7,1)

nx.draw(Graph, with_labels=True)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

# 1. Create the base Waxman graph
Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)

# 2. Manually add "Interconnects" to scramble the paths
# This creates a "multi-path" environment for the RL agent to explore
extra_edges = [
    (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1), # Your original edges
    (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),           # A secondary outer ring
    (5,12), (3,14), (6,11), (8,13), (4,10),                       # Cross-network "Shortcuts"
    (0,7), (2,9), (5,6)                                           # Random density
]

Graph.add_edges_from(extra_edges)

# 3. Setup Visualization
plt.figure(figsize=(10, 7))
pos = nx.spring_layout(Graph, seed=42) # Seed keeps the layout consistent

# Draw nodes and labels
nx.draw_networkx_nodes(Graph, pos, node_size=600, node_color='skyblue')
nx.draw_networkx_labels(Graph, pos, font_size=12, font_family='sans-serif')

# Draw edges with varying transparency to look like a "scrambled" complex net
nx.draw_networkx_edges(Graph, pos, width=1.5, alpha=0.6, edge_color='gray')

plt.title("Scrambled SDN Topology for RL Training")
plt.axis('off')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

# 1. Create the base graph (using your setup)
Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
extra_edges = [
    (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1), 
    (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),           
    (5,12), (3,14), (6,11), (8,13), (4,10),                       
    (0,7), (2,9), (5,6)                                           
]
Graph.add_edges_from(extra_edges)

# 2. Define Start and Destination
start_node = 12
end_node = 7

# 3. Simulate Congestion Logic
# We create a dictionary where each node is assigned 'red' (congested) or 'green' (clear)
# We ensure the start and end nodes are always green so the path is possible
node_colors = []
for node in Graph.nodes():
    if node == start_node or node == end_node:
        node_colors.append('lime') # Start/End are always clear
    else:
        # 30% chance of a node being congested
        status = 'red' if random.random() < 0.3 else 'lightgreen'
        node_colors.append(status)

# 4. Visualization
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(Graph, seed=42) 

# Draw edges
nx.draw_networkx_edges(Graph, pos, width=1.5, alpha=0.4, edge_color='gray')

# Draw nodes with the color list we generated
nx.draw_networkx_nodes(Graph, pos, node_size=800, node_color=node_colors, edgecolors='black')

# Label nodes
nx.draw_networkx_labels(Graph, pos, font_size=12, font_weight='bold')

# Special labels for Start and End
plt.text(pos[start_node][0], pos[start_node][1]+0.1, s="START (12)", bbox=dict(facecolor='white', alpha=0.5), horizontalalignment='center')
plt.text(pos[end_node][0], pos[end_node][1]+0.1, s="DESTINATION (7)", bbox=dict(facecolor='white', alpha=0.5), horizontalalignment='center')

plt.title("SDN Topology: Congestion Visualization (Red = High Congestion)")
plt.axis('off')
plt.show()

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import random
import time

def create_graph():

    # 1. Create the base graph (using your setup)
    Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
    extra_edges = [
        (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1),
        (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),
        (5,12), (3,14), (6,11), (8,13), (4,10),
        (0,7), (2,9), (5,6)
    ]
    Graph.add_edges_from(extra_edges)
    return Graph

def congestion_logic(Graph):
    # 2. Define Start and Destination
    start_node = 12
    end_node = 7

    # 3. Simulate Congestion Logic
    # We create a dictionary where each node is assigned 'red' (congested) or 'green' (clear)
    # We ensure the start and end nodes are always green so the path is possible
    node_colors = []
    for node in Graph.nodes():
        if node == start_node or node == end_node:
            node_colors.append('lime') # Start/End are always clear
        else:
            # 30% chance of a node being congested
            status = 'red' if random.random() < 0.3 else 'lightgreen'
            node_colors.append(status)
    return node_colors, start_node, end_node

def visualise(Graph, node_colors, start_node, end_node):
    # 4. Visualization
    plt.figure(figsize=(12, 8))
    pos = nx.spring_layout(Graph, seed=42)

    # Draw edges
    nx.draw_networkx_edges(Graph, pos, width=1.5, alpha=0.4, edge_color='gray')

    # Draw nodes with the color list we generated
    nx.draw_networkx_nodes(Graph, pos, node_size=800, node_color=node_colors, edgecolors='black')

    # Label nodes
    nx.draw_networkx_labels(Graph, pos, font_size=12, font_weight='bold')

    # Special labels for Start and End
    plt.text(pos[start_node][0], pos[start_node][1]+0.1, s="START (12)", bbox=dict(facecolor='white', alpha=0.5), horizontalalignment='center')
    plt.text(pos[end_node][0], pos[end_node][1]+0.1, s="DESTINATION (7)", bbox=dict(facecolor='white', alpha=0.5), horizontalalignment='center')

    plt.title("SDN Topology: Congestion Visualization (Red = High Congestion)")
    plt.axis('off')
    plt.show()

my_graph = create_graph()
#my_colors, my_start, my_end = congestion_logic(my_graph)
for i in range(10):
    my_colors, my_start, my_end = congestion_logic(my_graph)
    visualise(my_graph, my_colors, my_start, my_end)
#visualise(my_graph, my_colors, my_start, my_end)

# %%
Not safe code below this

# %% [markdown]
# Creating a Reinforcement Learning Agent

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from IPython.display import clear_output

# ==========================================
# 1. NETWORK & PYTORCH MODEL SETUP
# ==========================================
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        # 3-layer neural network based on Khodayari's approach
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.out = nn.Linear(64, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

def create_graph():
    Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
    extra_edges = [
        (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1),
        (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),
        (5,12), (3,14), (6,11), (8,13), (4,10),
        (0,7), (2,9), (5,6)
    ]
    Graph.add_edges_from(extra_edges)
    return Graph

def congestion_logic(Graph, start_node, end_node):
    node_colors = []
    binary_state = [] # RL needs numbers, not strings
    for node in Graph.nodes():
        if node == start_node or node == end_node:
            node_colors.append('lime')
            binary_state.append(0)
        else:
            if random.random() < 0.3:
                node_colors.append('red')
                binary_state.append(1) # 1 = Congested
            else:
                node_colors.append('lightgreen')
                binary_state.append(0) # 0 = Clear
    return node_colors, np.array(binary_state)

def get_state_tensor(current_node, binary_congestion):
    # Combine location and congestion into one input tensor
    pos_array = np.zeros(15)
    pos_array[current_node] = 1.0
    state = np.concatenate((pos_array, binary_congestion))
    return torch.FloatTensor(state).unsqueeze(0)

def visualise(Graph, pos, node_colors, start_node, end_node, path):
    clear_output(wait=True)
    plt.figure(figsize=(10, 6))
    nx.draw_networkx_edges(Graph, pos, width=1.5, alpha=0.4, edge_color='gray')
    nx.draw_networkx_nodes(Graph, pos, node_size=800, node_color=node_colors, edgecolors='black')
    nx.draw_networkx_labels(Graph, pos, font_size=12, font_weight='bold')
    
    # Draw the path the agent took in thick blue
    if path:
        path_edges = list(zip(path, path[1:]))
        nx.draw_networkx_edges(Graph, pos, edgelist=path_edges, width=4, edge_color='blue')

    plt.text(pos[start_node][0], pos[start_node][1]+0.1, s="START (12)", bbox=dict(facecolor='white', alpha=0.7), ha='center')
    plt.text(pos[end_node][0], pos[end_node][1]+0.1, s="DEST (7)", bbox=dict(facecolor='white', alpha=0.7), ha='center')
    plt.title("SDN Intelligent Routing Final Path")
    plt.axis('off')
    plt.show()

# ==========================================
# 2. TRAINING THE RL AGENT
# ==========================================
my_graph = create_graph()
pos = nx.spring_layout(my_graph, seed=42) # Calculate layout once!

start_node = 12
end_node = 7
num_nodes = 15

# Initialize DQN (Input: 30, Output: 15 Q-values for each node)
agent = DQN(30, 15)
optimizer = optim.Adam(agent.parameters(), lr=0.01)
loss_fn = nn.MSELoss()

episodes = 100
gamma = 0.9 # Discount factor
epsilon = 1.0 # Start by exploring 100% of the time
epsilon_decay = 0.95

print("Training RL Agent... Please wait.")

for i in range(episodes):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    current_node = start_node
    path_taken = [current_node]
    
    is_final_iteration = (i == episodes - 1)
    if is_final_iteration:
        epsilon = 0.0 # No random moves on the final test
        print("\n--- FINAL ITERATION ROUTING EXPLANATION ---")

    for step in range(15): # Max 15 steps to prevent infinite loops
        state_tensor = get_state_tensor(current_node, congestion_state)
        q_values = agent(state_tensor)
        
        neighbors = list(my_graph.neighbors(current_node))
        
        # Action Selection (Epsilon-Greedy)
        if random.random() < epsilon:
            next_node = random.choice(neighbors)
        else:
            # Mask invalid moves (nodes that are not neighbors)
            q_vals_numpy = q_values.detach().numpy()[0]
            valid_q_vals = {n: q_vals_numpy[n] for n in neighbors}
            next_node = max(valid_q_vals, key=valid_q_vals.get)
            
            # EXPLANATION LOGIC FOR FINAL ITERATION
            if is_final_iteration:
                print(f"Agent at Node {current_node}. Evaluating neighbors: {neighbors}")
                for n in neighbors:
                    status = "CONGESTED" if congestion_state[n] == 1 else "CLEAR"
                    print(f"  -> Neighbor {n} is {status}. Predicted Q-Value: {valid_q_vals[n]:.2f}")
                print(f"  ==> Chose Node {next_node} because it has the highest Q-Value.\n")

        path_taken.append(next_node)
        
        # Calculate Reward
        if next_node == end_node:
            reward = 100
            done = True
        elif congestion_state[next_node] == 1:
            reward = -20
            done = False
        else:
            reward = -1
            done = False
            
        # DQN Update (Bellman Equation)
        next_state_tensor = get_state_tensor(next_node, congestion_state)
        with torch.no_grad():
            next_q_values = agent(next_state_tensor)
            max_next_q = torch.max(next_q_values)
            
        target_q = q_values.clone()
        target_q[0][next_node] = reward + (gamma * max_next_q * (1 - int(done)))
        
        loss = loss_fn(q_values, target_q)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        current_node = next_node
        if done:
            if is_final_iteration:
                print("SUCCESS: Destination Reached!")
            break
            
    # Decay exploration rate
    epsilon = max(0.05, epsilon * epsilon_decay)

# 3. Final Visualization
visualise(my_graph, pos, my_colors, start_node, end_node, path_taken)

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from IPython.display import clear_output

# ==========================================
# 1. SETUP FUNCTIONS (Graph & Model)
# ==========================================
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.out = nn.Linear(64, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

def create_graph():
    Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
    extra_edges = [
        (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1),
        (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),
        (5,12), (3,14), (6,11), (8,13), (4,10),
        (0,7), (2,9), (5,6)
    ]
    Graph.add_edges_from(extra_edges)
    return Graph

def congestion_logic(Graph, start_node, end_node):
    node_colors = []
    binary_state = []
    for node in Graph.nodes():
        if node == start_node or node == end_node:
            node_colors.append('lime')
            binary_state.append(0)
        else:
            if random.random() < 0.3:
                node_colors.append('red')
                binary_state.append(1)
            else:
                node_colors.append('lightgreen')
                binary_state.append(0)
    return node_colors, np.array(binary_state)

def get_state_tensor(current_node, binary_congestion):
    pos_array = np.zeros(15)
    pos_array[current_node] = 1.0
    state = np.concatenate((pos_array, binary_congestion))
    return torch.FloatTensor(state).unsqueeze(0)

# ==========================================
# 2. TRAINING LOOP WITH LIVE DASHBOARD
# ==========================================
my_graph = create_graph()
pos = nx.spring_layout(my_graph, seed=42)

start_node = 12
end_node = 7
num_nodes = 15

agent = DQN(30, 15)
optimizer = optim.Adam(agent.parameters(), lr=0.01)
loss_fn = nn.MSELoss()

episodes = 50 # Reduced to 50 for faster live visualization
gamma = 0.9 
epsilon = 1.0 
epsilon_decay = 0.90

# We will track rewards here to plot the learning curve
rewards_history = []

for i in range(episodes):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    current_node = start_node
    path_taken = [current_node]
    episode_reward = 0
    
    is_final_iteration = (i == episodes - 1)
    if is_final_iteration:
        epsilon = 0.0 # Strict exploitation on the final test

    # Step through the network
    for step in range(15): 
        state_tensor = get_state_tensor(current_node, congestion_state)
        q_values = agent(state_tensor)
        neighbors = list(my_graph.neighbors(current_node))
        
        if random.random() < epsilon:
            next_node = random.choice(neighbors)
        else:
            q_vals_numpy = q_values.detach().numpy()[0]
            valid_q_vals = {n: q_vals_numpy[n] for n in neighbors}
            next_node = max(valid_q_vals, key=valid_q_vals.get)
            
            # Print explanation logic on the final step
            if is_final_iteration:
                print(f"Agent at {current_node} -> Chose {next_node} (Expected Value: {valid_q_vals[next_node]:.2f})")

        path_taken.append(next_node)
        
        if next_node == end_node:
            reward = 100
            done = True
        elif congestion_state[next_node] == 1:
            reward = -20
            done = False
        else:
            reward = -1
            done = False
            
        next_state_tensor = get_state_tensor(next_node, congestion_state)
        with torch.no_grad():
            next_q_values = agent(next_state_tensor)
            max_next_q = torch.max(next_q_values)
            
        target_q = q_values.clone()
        target_q[0][next_node] = reward + (gamma * max_next_q * (1 - int(done)))
        
        loss = loss_fn(q_values, target_q)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        current_node = next_node
        episode_reward += reward
        if done:
            break
            
    # Save the total reward for this episode
    rewards_history.append(episode_reward)
    epsilon = max(0.05, epsilon * epsilon_decay)

    # ---------------------------------------------------------
    # LIVE VISUALIZATION DASHBOARD
    # ---------------------------------------------------------
    clear_output(wait=True)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
    
    # --- Panel 1: The Network ---
    nx.draw_networkx_edges(my_graph, pos, ax=ax1, width=1.5, alpha=0.4, edge_color='gray')
    nx.draw_networkx_nodes(my_graph, pos, ax=ax1, node_size=600, node_color=my_colors, edgecolors='black')
    nx.draw_networkx_labels(my_graph, pos, ax=ax1, font_size=10, font_weight='bold')
    
    # Draw path
    path_edges = list(zip(path_taken, path_taken[1:]))
    nx.draw_networkx_edges(my_graph, pos, ax=ax1, edgelist=path_edges, width=4, edge_color='blue')
    
    ax1.text(pos[start_node][0], pos[start_node][1]+0.15, s="START", bbox=dict(facecolor='white', alpha=0.7), ha='center')
    ax1.text(pos[end_node][0], pos[end_node][1]+0.15, s="DEST", bbox=dict(facecolor='white', alpha=0.7), ha='center')
    ax1.set_title(f"Episode {i+1}/{episodes} | Network Path (Blue)")
    ax1.axis('off')

    # --- Panel 2: The Learning Curve ---
    ax2.plot(range(1, len(rewards_history) + 1), rewards_history, color='purple', marker='o', linestyle='-')
    ax2.set_title("Agent Learning Curve")
    ax2.set_xlabel("Episode")
    ax2.set_ylabel("Total Reward")
    ax2.grid(True, linestyle='--', alpha=0.6)
    
    # Draw a horizontal line representing the "Goal" (Reaching destination with minimal steps)
    ax2.axhline(y=100, color='green', linestyle='--', label='Max Reward Goal')
    ax2.legend()
    
    plt.tight_layout()
    plt.show()

print("\nTraining Complete! The learning curve shows how the agent adapted over time.")
# Out:
# Training Complete! The learning curve shows how the agent adapted over time.

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from IPython.display import clear_output

# ==========================================
# 1. SETUP FUNCTIONS (Graph & Model)
# ==========================================
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        # Widened the network slightly to handle complex patterns
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

def create_graph():
    Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
    extra_edges = [
        (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1),
        (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),
        (5,12), (3,14), (6,11), (8,13), (4,10),
        (0,7), (2,9), (5,6)
    ]
    Graph.add_edges_from(extra_edges)
    return Graph

def congestion_logic(Graph, start_node, end_node):
    node_colors = []
    binary_state = []
    for node in Graph.nodes():
        if node == start_node or node == end_node:
            node_colors.append('lime')
            binary_state.append(0)
        else:
            if random.random() < 0.35: # 35% chance of congestion
                node_colors.append('red')
                binary_state.append(1)
            else:
                node_colors.append('lightgreen')
                binary_state.append(0)
    return node_colors, np.array(binary_state)

def get_state_tensor(current_node, binary_congestion):
    pos_array = np.zeros(15)
    pos_array[current_node] = 1.0
    state = np.concatenate((pos_array, binary_congestion))
    return torch.FloatTensor(state).unsqueeze(0)

# ==========================================
# 2. TRAINING LOOP WITH DASHBOARD
# ==========================================
my_graph = create_graph()
pos = nx.spring_layout(my_graph, seed=42)

start_node = 12
end_node = 7
num_nodes = 15

agent = DQN(30, 15)
optimizer = optim.Adam(agent.parameters(), lr=0.005) # Lowered LR for stable learning
loss_fn = nn.MSELoss()

# INCREASED episodes so the network actually learns
episodes = 400 
gamma = 0.95 
epsilon = 1.0 
epsilon_decay = 0.985 # Slower decay ensures more exploration of the "other side"

rewards_history = []
moving_avg_rewards = [] # To smooth out the learning curve plot

for i in range(episodes):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    current_node = start_node
    path_taken = [current_node]
    episode_reward = 0
    
    is_final_iteration = (i == episodes - 1)
    if is_final_iteration:
        epsilon = 0.0 # Strict exploitation

    # Agent navigates
    for step in range(15): 
        state_tensor = get_state_tensor(current_node, congestion_state)
        q_values = agent(state_tensor)
        
        # KEY FIX: Force Rerouting by preventing backtracking
        unvisited_neighbors = [n for n in my_graph.neighbors(current_node) if n not in path_taken]
        
        # If the agent gets trapped in a dead end (all neighbors visited)
        if len(unvisited_neighbors) == 0:
            reward = -50 # Massive penalty for getting stuck
            target_q = q_values.clone()
            target_q[0][current_node] = reward
            loss = loss_fn(q_values, target_q)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            episode_reward += reward
            break # End the episode

        if random.random() < epsilon:
            next_node = random.choice(unvisited_neighbors)
        else:
            q_vals_numpy = q_values.detach().numpy()[0]
            valid_q_vals = {n: q_vals_numpy[n] for n in unvisited_neighbors}
            next_node = max(valid_q_vals, key=valid_q_vals.get)

        path_taken.append(next_node)
        
        # KEY FIX: Sharper penalties
        if next_node == end_node:
            reward = 100
            done = True
        elif congestion_state[next_node] == 1:
            reward = -30 # Hitting congestion hurts more now
            done = False
        else:
            reward = -1 # Clear path
            done = False
            
        next_state_tensor = get_state_tensor(next_node, congestion_state)
        with torch.no_grad():
            next_q_values = agent(next_state_tensor)
            max_next_q = torch.max(next_q_values)
            
        target_q = q_values.clone()
        target_q[0][next_node] = reward + (gamma * max_next_q * (1 - int(done)))
        
        loss = loss_fn(q_values, target_q)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        current_node = next_node
        episode_reward += reward
        if done:
            break
            
    rewards_history.append(episode_reward)
    
    # Calculate moving average for a cleaner graph
    if len(rewards_history) >= 10:
        moving_avg_rewards.append(np.mean(rewards_history[-10:]))
    else:
        moving_avg_rewards.append(episode_reward)

    epsilon = max(0.01, epsilon * epsilon_decay)

    # ---------------------------------------------------------
    # LIVE DASHBOARD (Updates every 20 episodes to speed up training)
    # ---------------------------------------------------------
    if i % 20 == 0 or is_final_iteration:
        clear_output(wait=True)
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        
        # --- Panel 1: The Network ---
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, width=1.5, alpha=0.4, edge_color='gray')
        nx.draw_networkx_nodes(my_graph, pos, ax=ax1, node_size=600, node_color=my_colors, edgecolors='black')
        nx.draw_networkx_labels(my_graph, pos, ax=ax1, font_size=10, font_weight='bold')
        
        path_edges = list(zip(path_taken, path_taken[1:]))
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, edgelist=path_edges, width=4, edge_color='blue')
        
        ax1.text(pos[start_node][0], pos[start_node][1]+0.15, s="START", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.text(pos[end_node][0], pos[end_node][1]+0.15, s="DEST", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.set_title(f"Episode {i+1}/{episodes} | Epsilon: {epsilon:.2f}\nPath Taken: {path_taken}")
        ax1.axis('off')

        # --- Panel 2: The Learning Curve ---
        ax2.plot(range(1, len(moving_avg_rewards) + 1), moving_avg_rewards, color='purple', linewidth=2, label='10-Ep Moving Avg')
        ax2.scatter(range(1, len(rewards_history) + 1), rewards_history, color='gray', alpha=0.3, s=10, label='Raw Reward')
        ax2.set_title("Agent Learning Curve (Converging on Best Routes)")
        ax2.set_xlabel("Episode")
        ax2.set_ylabel("Reward")
        ax2.grid(True, linestyle='--', alpha=0.6)
        
        ax2.axhline(y=100, color='green', linestyle='--', label='Max Reward Goal')
        ax2.legend()
        
        plt.tight_layout()
        plt.show()

print("\nTraining Complete! Notice how the path now curves AROUND the red nodes.")
if is_final_iteration:
    print(f"Final Path Chosen: {path_taken}")
# Out:
# Training Complete! Notice how the path now curves AROUND the red nodes.
# Final Path Chosen: [12, 5, 2, 9, 3, 6, 8, 4, 0, 1, 7]

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
from IPython.display import clear_output

# ==========================================
# 1. SETUP FUNCTIONS (Graph & Model)
# ==========================================
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_size, 128) # Widened for better memory
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

def create_graph():
    Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
    extra_edges = [
        (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1),
        (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),
        (5,12), (3,14), (6,11), (8,13), (4,10),
        (0,7), (2,9), (5,6)
    ]
    Graph.add_edges_from(extra_edges)
    return Graph

def congestion_logic(Graph, start_node, end_node):
    # FIX 1: Guarantee at least one clear path exists so it's never impossible
    guaranteed_path = nx.shortest_path(Graph, start_node, end_node)
    
    node_colors = ['lightgreen'] * 15
    binary_state = np.zeros(15)
    
    for node in Graph.nodes():
        if node in guaranteed_path:
            continue # Leave guaranteed path as green
        else:
            if random.random() < 0.7: # 40% chance other nodes are congested
                node_colors[node] = 'red'
                binary_state[node] = 1
                
    return node_colors, binary_state

def get_state_tensor(current_node, binary_congestion):
    pos_array = np.zeros(15)
    pos_array[current_node] = 1.0
    state = np.concatenate((pos_array, binary_congestion))
    return torch.FloatTensor(state).unsqueeze(0)

# ==========================================
# 2. TRAINING LOOP WITH REPLAY BUFFER
# ==========================================
my_graph = create_graph()
pos = nx.spring_layout(my_graph, seed=42)

start_node = 12
end_node = 7

agent = DQN(30, 15)
optimizer = optim.Adam(agent.parameters(), lr=0.005)
loss_fn = nn.MSELoss()

# FIX 2: Experience Replay (Memory Bank)
memory = deque(maxlen=2000) 
batch_size = 32

episodes = 800 # Increased episodes so the AI has time to learn
gamma = 0.95 
epsilon = 1.0 
epsilon_decay = 0.99 

rewards_history = []
moving_avg_rewards = [] 

print("Training Deep Q-Network... Please wait (takes ~10 seconds).")

for i in range(episodes):
    # Change the network congestion map dynamically
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    
    current_node = start_node
    path_taken = [current_node]
    episode_reward = 0
    
    is_final_iteration = (i == episodes - 1)
    if is_final_iteration:
        epsilon = 0.0 # Strict exploitation on the final test

    for step in range(15): 
        state_tensor = get_state_tensor(current_node, congestion_state)
        
        # Action Selection
        if random.random() < epsilon:
            next_node = random.choice(list(my_graph.neighbors(current_node)))
        else:
            q_values = agent(state_tensor)
            q_vals_numpy = q_values.detach().numpy()[0]
            valid_q_vals = {n: q_vals_numpy[n] for n in my_graph.neighbors(current_node)}
            next_node = max(valid_q_vals, key=valid_q_vals.get)
            
            if is_final_iteration:
                print(f"Agent at Node {current_node}. Best expected value is neighbor {next_node} (Q: {valid_q_vals[next_node]:.2f})")

        # FIX 3: Advanced Reward Logic
        if next_node == end_node:
            reward = 100
            done = True
        elif next_node in path_taken:
            reward = -15 # Penalize loops heavily!
            done = False
        elif congestion_state[next_node] == 1:
            reward = -30 # Penalize congestion heavily!
            done = False
        else:
            reward = -1 # Small penalty to encourage fastest route
            done = False
            
        next_state_tensor = get_state_tensor(next_node, congestion_state)
        
        # Save to memory
        memory.append((state_tensor, next_node, reward, next_state_tensor, done))
        
        # Train PyTorch model using a Batch from memory
        if len(memory) > batch_size:
            batch = random.sample(memory, batch_size)
            optimizer.zero_grad()
            loss = 0
            for s, a, r, n_s, d in batch:
                q_val = agent(s)[0][a] # Q-value of chosen action
                max_next_q = agent(n_s).max() # Best future value
                target = r + gamma * max_next_q * (1 - int(d))
                
                # We use MSE Loss between predicted Q and target Q
                loss += loss_fn(q_val, target.detach()) 
            
            loss = loss / batch_size
            loss.backward()
            optimizer.step()
        
        path_taken.append(next_node)
        current_node = next_node
        episode_reward += reward
        
        if done:
            break
            
    rewards_history.append(episode_reward)
    moving_avg_rewards.append(np.mean(rewards_history[-20:])) # 20-episode smooth average
    epsilon = max(0.01, epsilon * epsilon_decay)

    # ---------------------------------------------------------
    # LIVE DASHBOARD (Updates every 100 episodes to train fast)
    # ---------------------------------------------------------
    if i % 100 == 0 or is_final_iteration:
        clear_output(wait=True)
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        
        # --- Panel 1: The Network ---
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, width=1.5, alpha=0.4, edge_color='gray')
        nx.draw_networkx_nodes(my_graph, pos, ax=ax1, node_size=600, node_color=my_colors, edgecolors='black')
        nx.draw_networkx_labels(my_graph, pos, ax=ax1, font_size=10, font_weight='bold')
        
        path_edges = list(zip(path_taken, path_taken[1:]))
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, edgelist=path_edges, width=4, edge_color='blue')
        
        ax1.text(pos[start_node][0], pos[start_node][1]+0.15, s="START", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.text(pos[end_node][0], pos[end_node][1]+0.15, s="DEST", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.set_title(f"Episode {i}/{episodes} | Epsilon: {epsilon:.2f}\nFinal Path: {path_taken}")
        ax1.axis('off')

        # --- Panel 2: The Learning Curve ---
        ax2.plot(range(1, len(moving_avg_rewards) + 1), moving_avg_rewards, color='purple', linewidth=2, label='20-Ep Moving Avg')
        ax2.scatter(range(1, len(rewards_history) + 1), rewards_history, color='gray', alpha=0.2, s=10, label='Raw Reward')
        ax2.set_title("Agent Learning Curve (Converging on Best Routes)")
        ax2.set_xlabel("Episode")
        ax2.set_ylabel("Reward")
        ax2.grid(True, linestyle='--', alpha=0.6)
        ax2.axhline(y=100, color='green', linestyle='--', label='Max Reward Goal')
        ax2.legend()
        
        plt.tight_layout()
        plt.show()

print("\nSuccess! The agent successfully avoided the congestion to reach the destination.")
# Out:
# Success! The agent successfully avoided the congestion to reach the destination.

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
from IPython.display import clear_output

# ==========================================
# 1. SETUP FUNCTIONS (Graph & Model)
# ==========================================
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_size, 128) 
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

def create_graph():
    Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
    extra_edges = [
        (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1),
        (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),
        (5,12), (3,14), (6,11), (8,13), (4,10),
        (0,7), (2,9), (5,6)
    ]
    Graph.add_edges_from(extra_edges)
    return Graph

def congestion_logic(Graph, start_node, end_node):
    guaranteed_path = nx.shortest_path(Graph, start_node, end_node)
    
    node_colors = ['lightgreen'] * 15
    binary_state = np.zeros(15)
    
    for node in Graph.nodes():
        if node in guaranteed_path:
            continue 
        else:
            if random.random() < 0.8: 
                node_colors[node] = 'red'
                binary_state[node] = 1
                
    return node_colors, binary_state

def get_state_tensor(current_node, binary_congestion):
    pos_array = np.zeros(15)
    pos_array[current_node] = 1.0
    state = np.concatenate((pos_array, binary_congestion))
    return torch.FloatTensor(state).unsqueeze(0)

# ==========================================
# 2. TRAINING LOOP WITH CONSOLE LOGGING
# ==========================================
my_graph = create_graph()
pos = nx.spring_layout(my_graph, seed=42)

start_node = 12
end_node = 7

agent = DQN(30, 15)
optimizer = optim.Adam(agent.parameters(), lr=0.005)
loss_fn = nn.MSELoss()

memory = deque(maxlen=2000) 
batch_size = 32

episodes = 5000 
gamma = 0.95 
epsilon = 1.0 
epsilon_decay = 0.99 

rewards_history = []
moving_avg_rewards = [] 

# --- NEW: Variables for tracking internal progress ---
console_logs = []
successes_in_window = 0

print("Training Deep Q-Network... Please wait.")

for i in range(episodes):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    
    current_node = start_node
    path_taken = [current_node]
    episode_reward = 0
    
    is_final_iteration = (i == episodes - 1)
    if is_final_iteration:
        epsilon = 0.0 
        console_logs.append("\n" + "="*50)
        console_logs.append("FINAL EPISODE: INTERNAL DECISION LOGIC")
        console_logs.append("="*50)

    for step in range(15): 
        state_tensor = get_state_tensor(current_node, congestion_state)
        
        # Action Selection
        if random.random() < epsilon:
            next_node = random.choice(list(my_graph.neighbors(current_node)))
        else:
            q_values = agent(state_tensor)
            q_vals_numpy = q_values.detach().numpy()[0]
            valid_q_vals = {n: q_vals_numpy[n] for n in my_graph.neighbors(current_node)}
            next_node = max(valid_q_vals, key=valid_q_vals.get)
            
            # --- NEW: Print logic on final iteration ---
            if is_final_iteration:
                log_str = f"Step {step+1} | At Node {current_node} -> Evaluated Neighbors: "
                for n, q in valid_q_vals.items():
                    color = "RED" if congestion_state[n] == 1 else "GREEN"
                    log_str += f"[{n} ({color}): Q={q:.1f}] "
                log_str += f" ==> Chose {next_node}"
                console_logs.append(log_str)

        # Reward Logic
        if next_node == end_node:
            reward = 100
            done = True
            successes_in_window += 1 # Track success
        elif next_node in path_taken:
            reward = -15 
            done = False
        elif congestion_state[next_node] == 1:
            reward = -30 
            done = False
        else:
            reward = -1 
            done = False
            
        next_state_tensor = get_state_tensor(next_node, congestion_state)
        
        memory.append((state_tensor, next_node, reward, next_state_tensor, done))
        
        if len(memory) > batch_size:
            batch = random.sample(memory, batch_size)
            optimizer.zero_grad()
            loss = 0
            for s, a, r, n_s, d in batch:
                q_val = agent(s)[0][a] 
                max_next_q = agent(n_s).max() 
                target = r + gamma * max_next_q * (1 - int(d))
                loss += loss_fn(q_val, target.detach()) 
            
            loss = loss / batch_size
            loss.backward()
            optimizer.step()
        
        path_taken.append(next_node)
        current_node = next_node
        episode_reward += reward
        
        if done:
            if is_final_iteration:
                console_logs.append(f"SUCCESS: Reached Destination {end_node}!")
            break
            
    rewards_history.append(episode_reward)
    moving_avg_rewards.append(np.mean(rewards_history[-20:])) 
    epsilon = max(0.01, epsilon * epsilon_decay)

    # --- NEW: Generate a status log every 50 episodes ---
    if (i + 1) % 50 == 0 and not is_final_iteration:
        avg_rew = np.mean(rewards_history[-50:])
        console_logs.append(f"-> Episode {i+1:3d}/{episodes} | Epsilon: {epsilon:.2f} | Avg Reward (Last 50): {avg_rew:5.1f} | Success Rate: {successes_in_window}/50")
        successes_in_window = 0 # Reset window counter

    # ---------------------------------------------------------
    # LIVE DASHBOARD 
    # ---------------------------------------------------------
    if i % 100 == 0 or is_final_iteration:
        clear_output(wait=True)
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, width=1.5, alpha=0.4, edge_color='gray')
        nx.draw_networkx_nodes(my_graph, pos, ax=ax1, node_size=600, node_color=my_colors, edgecolors='black')
        nx.draw_networkx_labels(my_graph, pos, ax=ax1, font_size=10, font_weight='bold')
        
        path_edges = list(zip(path_taken, path_taken[1:]))
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, edgelist=path_edges, width=4, edge_color='blue')
        
        ax1.text(pos[start_node][0], pos[start_node][1]+0.15, s="START", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.text(pos[end_node][0], pos[end_node][1]+0.15, s="DEST", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.set_title(f"Episode {i}/{episodes} | Epsilon: {epsilon:.2f}\nFinal Path: {path_taken}")
        ax1.axis('off')

        ax2.plot(range(1, len(moving_avg_rewards) + 1), moving_avg_rewards, color='purple', linewidth=2, label='20-Ep Moving Avg')
        ax2.scatter(range(1, len(rewards_history) + 1), rewards_history, color='gray', alpha=0.2, s=10, label='Raw Reward')
        ax2.set_title("Agent Learning Curve (Converging on Best Routes)")
        ax2.set_xlabel("Episode")
        ax2.set_ylabel("Reward")
        ax2.grid(True, linestyle='--', alpha=0.6)
        ax2.axhline(y=100, color='green', linestyle='--', label='Max Reward Goal')
        ax2.legend()
        
        plt.tight_layout()
        plt.show()
        
        # Print all accumulated logs underneath the plot
        for log in console_logs[-15:]: # Show last 15 lines so it doesn't get too long
            print(log)
# Out:
# -> Episode 4600/5000 | Epsilon: 0.01 | Avg Reward (Last 50):  94.7 | Success Rate: 50/50
# -> Episode 4650/5000 | Epsilon: 0.01 | Avg Reward (Last 50):  98.0 | Success Rate: 50/50
# -> Episode 4700/5000 | Epsilon: 0.01 | Avg Reward (Last 50):  97.4 | Success Rate: 50/50
# -> Episode 4750/5000 | Epsilon: 0.01 | Avg Reward (Last 50):  97.7 | Success Rate: 50/50
# -> Episode 4800/5000 | Epsilon: 0.01 | Avg Reward (Last 50):  95.9 | Success Rate: 50/50
# -> Episode 4850/5000 | Epsilon: 0.01 | Avg Reward (Last 50):  97.4 | Success Rate: 50/50
# -> Episode 4900/5000 | Epsilon: 0.01 | Avg Reward (Last 50):  97.1 | Success Rate: 50/50
# -> Episode 4950/5000 | Epsilon: 0.01 | Avg Reward (Last 50):  97.4 | Success Rate: 50/50
#
# ==================================================
# FINAL EPISODE: INTERNAL DECISION LOGIC
# ==================================================
# Step 1 | At Node 12 -> Evaluated Neighbors: [11 (RED): Q=69.5] [13 (RED): Q=66.0] [5 (GREEN): Q=86.7]  ==> Chose 5
# Step 2 | At Node 5 -> Evaluated Neighbors: [1 (GREEN): Q=90.7] [2 (RED): Q=55.8] [12 (GREEN): Q=84.9] [6 (RED): Q=62.7]  ==> Chose 1
# Step 3 | At Node 1 -> Evaluated Neighbors: [0 (GREEN): Q=79.0] [5 (GREEN): Q=83.1] [7 (GREEN): Q=97.7]  ==> Chose 7
# SUCCESS: Reached Destination 7!

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
from IPython.display import clear_output
import time

# ==========================================
# 1. SETUP FUNCTIONS (Graph & Model)
# ==========================================
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_size, 128) 
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

def create_graph():
    Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
    extra_edges = [
        (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1),
        (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),
        (5,12), (3,14), (6,11), (8,13), (4,10),
        (0,7), (2,9), (5,6)
    ]
    Graph.add_edges_from(extra_edges)
    return Graph

def congestion_logic(Graph, start_node, end_node):
    # TRULY DYNAMIC LOGIC: Randomize everything, then check if a path exists.
    # If no path exists, reroll the congestion map.
    while True:
        node_colors = ['lightgreen'] * 15
        binary_state = np.zeros(15)
        
        for node in Graph.nodes():
            if node == start_node or node == end_node:
                continue 
            
            # 35% chance of congestion. (Too high, like 80%, makes 99% of maps impossible)
            if random.random() < 0.35: 
                node_colors[node] = 'red'
                binary_state[node] = 1
                
        # Check if the generated map is solvable
        green_nodes = [n for n in Graph.nodes() if binary_state[n] == 0]
        subgraph = Graph.subgraph(green_nodes)
        
        if nx.has_path(subgraph, start_node, end_node):
            return node_colors, binary_state

def get_state_tensor(current_node, binary_congestion):
    pos_array = np.zeros(15)
    pos_array[current_node] = 1.0
    state = np.concatenate((pos_array, binary_congestion))
    return torch.FloatTensor(state).unsqueeze(0)

# ==========================================
# 2. TRAINING LOOP
# ==========================================
my_graph = create_graph()
pos = nx.spring_layout(my_graph, seed=42)

start_node = 12
end_node = 7

agent = DQN(30, 15)
optimizer = optim.Adam(agent.parameters(), lr=0.005)
loss_fn = nn.MSELoss()

memory = deque(maxlen=2000) 
batch_size = 32

episodes = 2000 # 2000 is plenty for this dynamic setup
gamma = 0.95 
epsilon = 1.0 
epsilon_decay = 0.995 # Slower decay so it explores the dynamic maps thoroughly

rewards_history = []
moving_avg_rewards = [] 
console_logs = []
successes_in_window = 0

print("Training Deep Q-Network on Dynamic Maps... Please wait (~15 seconds).")

for i in range(episodes):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    
    current_node = start_node
    path_taken = [current_node]
    episode_reward = 0

    for step in range(15): 
        state_tensor = get_state_tensor(current_node, congestion_state)
        
        # Action Selection
        if random.random() < epsilon:
            next_node = random.choice(list(my_graph.neighbors(current_node)))
        else:
            q_values = agent(state_tensor)
            q_vals_numpy = q_values.detach().numpy()[0]
            valid_q_vals = {n: q_vals_numpy[n] for n in my_graph.neighbors(current_node)}
            next_node = max(valid_q_vals, key=valid_q_vals.get)

        # Reward Logic
        if next_node == end_node:
            reward = 100
            done = True
            successes_in_window += 1
        elif next_node in path_taken:
            reward = -20 
            done = False
        elif congestion_state[next_node] == 1:
            reward = -30 
            done = False
        else:
            reward = -1 
            done = False
            
        next_state_tensor = get_state_tensor(next_node, congestion_state)
        
        memory.append((state_tensor, next_node, reward, next_state_tensor, done))
        
        if len(memory) > batch_size:
            batch = random.sample(memory, batch_size)
            optimizer.zero_grad()
            loss = 0
            for s, a, r, n_s, d in batch:
                q_val = agent(s)[0][a] 
                max_next_q = agent(n_s).max() 
                target = r + gamma * max_next_q * (1 - int(d))
                loss += loss_fn(q_val, target.detach()) 
            
            loss = loss / batch_size
            loss.backward()
            optimizer.step()
        
        path_taken.append(next_node)
        current_node = next_node
        episode_reward += reward
        
        if done:
            break
            
    rewards_history.append(episode_reward)
    moving_avg_rewards.append(np.mean(rewards_history[-20:])) 
    epsilon = max(0.01, epsilon * epsilon_decay)

    if (i + 1) % 100 == 0:
        avg_rew = np.mean(rewards_history[-100:])
        print(f"Episode {i+1:4d}/{episodes} | Epsilon: {epsilon:.2f} | Avg Reward (Last 100): {avg_rew:5.1f} | Success Rate: {successes_in_window}%")
        successes_in_window = 0

print("\nTraining Complete! Launching Dynamic Testing Phase...")
time.sleep(2)

# ==========================================
# 3. DYNAMIC TESTING PHASE (Shows 3 different maps)
# ==========================================


for test_run in range(3):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    current_node = start_node
    path_taken = [current_node]
    
    # Run the trained agent (Epsilon = 0)
    for step in range(15):
        state_tensor = get_state_tensor(current_node, congestion_state)
        q_values = agent(state_tensor)
        q_vals_numpy = q_values.detach().numpy()[0]
        valid_q_vals = {n: q_vals_numpy[n] for n in my_graph.neighbors(current_node)}
        next_node = max(valid_q_vals, key=valid_q_vals.get)
        
        path_taken.append(next_node)
        if next_node == end_node:
            break
        current_node = next_node

    # Draw the specific test case
    clear_output(wait=True)
    fig, ax1 = plt.subplots(figsize=(10, 8))
    
    nx.draw_networkx_edges(my_graph, pos, ax=ax1, width=1.5, alpha=0.4, edge_color='gray')
    nx.draw_networkx_nodes(my_graph, pos, ax=ax1, node_size=800, node_color=my_colors, edgecolors='black')
    nx.draw_networkx_labels(my_graph, pos, ax=ax1, font_size=12, font_weight='bold')
    
    path_edges = list(zip(path_taken, path_taken[1:]))
    nx.draw_networkx_edges(my_graph, pos, ax=ax1, edgelist=path_edges, width=5, edge_color='blue')
    
    ax1.text(pos[start_node][0], pos[start_node][1]+0.15, s="START", bbox=dict(facecolor='white', alpha=0.8), ha='center')
    ax1.text(pos[end_node][0], pos[end_node][1]+0.15, s="DEST", bbox=dict(facecolor='white', alpha=0.8), ha='center')
    
    ax1.set_title(f"Dynamic Test {test_run+1}/3\nThe trained AI generated a completely new path based on this specific congestion map!", fontsize=14)
    ax1.axis('off')
    
    plt.show()
    print(f"Path taken for Test {test_run+1}: {path_taken}")
    time.sleep(3) # Pause so you can visually analyze the graph before the next test loads
# Out:
# Path taken for Test 3: [12, 5, 1, 7]

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
from IPython.display import clear_output
import time

# ==========================================
# 1. SETUP FUNCTIONS (Graph & Model)
# ==========================================
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_size, 128) 
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

def create_graph():
    # 15-node base topology
    Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
    extra_edges = [
        (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1),
        (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),
        (5,12), (3,14), (6,11), (8,13), (4,10),
        (0,7), (2,9), (5,6)
    ]
    Graph.add_edges_from(extra_edges)
    return Graph

def congestion_logic(Graph, start_node, end_node):
    # TRULY DYNAMIC LOGIC: Randomize until a valid path exists
    while True:
        node_colors = ['lightgreen'] * 15
        binary_state = np.zeros(15)
        
        for node in Graph.nodes():
            if node == start_node or node == end_node:
                continue 
            
            # 35% chance of congestion on any node
            if random.random() < 0.35: 
                node_colors[node] = 'red'
                binary_state[node] = 1
                
        # Check if map is logically solvable
        green_nodes = [n for n in Graph.nodes() if binary_state[n] == 0]
        subgraph = Graph.subgraph(green_nodes)
        if nx.has_path(subgraph, start_node, end_node):
            return node_colors, binary_state

def get_state_tensor(current_node, binary_congestion):
    pos_array = np.zeros(15)
    pos_array[current_node] = 1.0
    state = np.concatenate((pos_array, binary_congestion))
    return torch.FloatTensor(state).unsqueeze(0)

# ==========================================
# 2. TRAINING LOOP WITH LIVE GRAPHING
# ==========================================
my_graph = create_graph()
pos = nx.spring_layout(my_graph, seed=42) # Static layout for visual stability

start_node = 12
end_node = 7

# Initialize PyTorch Agent
agent = DQN(30, 15)
optimizer = optim.Adam(agent.parameters(), lr=0.005)
loss_fn = nn.MSELoss()

memory = deque(maxlen=2000) 
batch_size = 32

episodes = 1000 # 1000 iterations for training
gamma = 0.95 
epsilon = 1.0 
epsilon_decay = 0.99 

# Data tracking for our graphs
rewards_history = []
moving_avg_rewards = [] 

print("Training Deep Q-Network... Please wait.")
time.sleep(1)

for i in range(episodes):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    
    current_node = start_node
    path_taken = [current_node]
    episode_reward = 0

    for step in range(15): 
        state_tensor = get_state_tensor(current_node, congestion_state)
        
        # Action Selection (Explore vs Exploit)
        if random.random() < epsilon:
            next_node = random.choice(list(my_graph.neighbors(current_node)))
        else:
            q_values = agent(state_tensor)
            q_vals_numpy = q_values.detach().numpy()[0]
            valid_q_vals = {n: q_vals_numpy[n] for n in my_graph.neighbors(current_node)}
            next_node = max(valid_q_vals, key=valid_q_vals.get)

        # Environment Feedback (Reward)
        if next_node == end_node:
            reward = 100
            done = True
        elif next_node in path_taken:
            reward = -20 # Loop penalty
            done = False
        elif congestion_state[next_node] == 1:
            reward = -30 # Congestion penalty
            done = False
        else:
            reward = -1  # Step penalty
            done = False
            
        next_state_tensor = get_state_tensor(next_node, congestion_state)
        
        # Save to Replay Memory
        memory.append((state_tensor, next_node, reward, next_state_tensor, done))
        
        # Train PyTorch model
        if len(memory) > batch_size:
            batch = random.sample(memory, batch_size)
            optimizer.zero_grad()
            loss = 0
            for s, a, r, n_s, d in batch:
                q_val = agent(s)[0][a] 
                max_next_q = agent(n_s).max() 
                target = r + gamma * max_next_q * (1 - int(d))
                loss += loss_fn(q_val, target.detach()) 
            
            loss = loss / batch_size
            loss.backward()
            optimizer.step()
        
        path_taken.append(next_node)
        current_node = next_node
        episode_reward += reward
        
        if done:
            break
            
    # Track the data over each iteration
    rewards_history.append(episode_reward)
    moving_avg_rewards.append(np.mean(rewards_history[-20:])) 
    epsilon = max(0.01, epsilon * epsilon_decay)

    # ---------------------------------------------------------
    # DASHBOARD: UPDATE GRAPH EVERY 50 ITERATIONS
    # ---------------------------------------------------------
    if (i + 1) % 50 == 0:
        clear_output(wait=True)
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        
        # --- LEFT: Physical Network ---
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, width=1.5, alpha=0.4, edge_color='gray')
        nx.draw_networkx_nodes(my_graph, pos, ax=ax1, node_size=600, node_color=my_colors, edgecolors='black')
        nx.draw_networkx_labels(my_graph, pos, ax=ax1, font_size=10, font_weight='bold')
        
        path_edges = list(zip(path_taken, path_taken[1:]))
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, edgelist=path_edges, width=4, edge_color='blue')
        
        ax1.text(pos[start_node][0], pos[start_node][1]+0.15, s="START", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.text(pos[end_node][0], pos[end_node][1]+0.15, s="DEST", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.set_title(f"Episode {i+1}/{episodes} | Epsilon: {epsilon:.2f}\nCurrent Path: {path_taken}")
        ax1.axis('off')

        # --- RIGHT: Data Graph Over Each Iteration ---
        ax2.plot(range(1, len(moving_avg_rewards) + 1), moving_avg_rewards, color='purple', linewidth=2.5, label='20-Iteration Moving Avg')
        ax2.scatter(range(1, len(rewards_history) + 1), rewards_history, color='gray', alpha=0.25, s=15, label='Raw Reward per Iteration')
        ax2.set_title("AI Learning Data (Reward vs. Iteration)")
        ax2.set_xlabel("Iteration (Episode)")
        ax2.set_ylabel("Total Reward")
        ax2.grid(True, linestyle='--', alpha=0.6)
        ax2.axhline(y=100, color='green', linestyle='--', label='Target Goal (+100)')
        ax2.legend(loc="lower right")
        
        plt.tight_layout()
        plt.show()

print("\nTraining Complete! Launching Final Dynamic Testing Phase...")
time.sleep(2)
clear_output(wait=True)

# ==========================================
# 3. DYNAMIC TESTING PHASE
# ==========================================
print("=== DYNAMIC ROUTING TEST RESULTS ===")

for test_run in range(3):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    current_node = start_node
    path_taken = [current_node]
    
    # Run fully trained agent (Epsilon = 0)
    for step in range(15):
        state_tensor = get_state_tensor(current_node, congestion_state)
        q_values = agent(state_tensor)
        q_vals_numpy = q_values.detach().numpy()[0]
        valid_q_vals = {n: q_vals_numpy[n] for n in my_graph.neighbors(current_node)}
        next_node = max(valid_q_vals, key=valid_q_vals.get)
        
        path_taken.append(next_node)
        if next_node == end_node:
            break
        current_node = next_node

    # Draw test maps sequentially (Stacked)
    fig, ax1 = plt.subplots(figsize=(8, 5))
    
    nx.draw_networkx_edges(my_graph, pos, ax=ax1, width=1.5, alpha=0.4, edge_color='gray')
    nx.draw_networkx_nodes(my_graph, pos, ax=ax1, node_size=600, node_color=my_colors, edgecolors='black')
    nx.draw_networkx_labels(my_graph, pos, ax=ax1, font_size=10, font_weight='bold')
    
    path_edges = list(zip(path_taken, path_taken[1:]))
    nx.draw_networkx_edges(my_graph, pos, ax=ax1, edgelist=path_edges, width=4, edge_color='blue')
    
    ax1.text(pos[start_node][0], pos[start_node][1]+0.15, s="START", bbox=dict(facecolor='white', alpha=0.8), ha='center')
    ax1.text(pos[end_node][0], pos[end_node][1]+0.15, s="DEST", bbox=dict(facecolor='white', alpha=0.8), ha='center')
    ax1.set_title(f"Dynamic Test {test_run+1}/3 | Path Taken: {path_taken}\nThe AI automatically found the clear route!", fontsize=12)
    ax1.axis('off')
    
    plt.show()
# Out:
# === DYNAMIC ROUTING TEST RESULTS ===

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
from IPython.display import clear_output
import time

# ==========================================
# 1. SETUP FUNCTIONS (Graph & Model)
# ==========================================
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_size, 128) 
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

def create_graph():
    # 15-node base topology
    Graph = nx.waxman_graph(15, beta=0.4, alpha=0.1)
    extra_edges = [
        (0,1), (0,4), (1,5), (2,5), (6,8), (7,9), (9,3), (8,4), (7,1),
        (2,10), (10,11), (11,12), (12,13), (13,14), (14,0),
        (5,12), (3,14), (6,11), (8,13), (4,10),
        (0,7), (2,9), (5,6)
    ]
    Graph.add_edges_from(extra_edges)
    return Graph

def congestion_logic(Graph, start_node, end_node):
    # TRULY DYNAMIC LOGIC: Randomize until a valid path exists
    while True:
        node_colors = ['lightgreen'] * 15
        binary_state = np.zeros(15)
        
        for node in Graph.nodes():
            if node == start_node or node == end_node:
                continue 
            
            # 35% chance of congestion on any node
            if random.random() < 0.70: 
                node_colors[node] = 'red'
                binary_state[node] = 1
                
        # Check if map is logically solvable
        green_nodes = [n for n in Graph.nodes() if binary_state[n] == 0]
        subgraph = Graph.subgraph(green_nodes)
        if nx.has_path(subgraph, start_node, end_node):
            return node_colors, binary_state

def get_state_tensor(current_node, binary_congestion):
    pos_array = np.zeros(15)
    pos_array[current_node] = 1.0
    state = np.concatenate((pos_array, binary_congestion))
    return torch.FloatTensor(state).unsqueeze(0)

# ==========================================
# 2. TRAINING LOOP WITH LIVE GRAPHING
# ==========================================
my_graph = create_graph()
pos = nx.spring_layout(my_graph, seed=42) # Static layout for visual stability

start_node = 12
end_node = 7

# Initialize PyTorch Agent
agent = DQN(30, 15)
optimizer = optim.Adam(agent.parameters(), lr=0.005)
loss_fn = nn.MSELoss()

memory = deque(maxlen=2000) 
batch_size = 32

episodes = 1000 # 1000 iterations for training
gamma = 0.95 
epsilon = 1.0 
epsilon_decay = 0.99 

# Data tracking for our graphs
rewards_history = []
moving_avg_rewards = [] 

print("Training Deep Q-Network... Please wait.")
time.sleep(1)

for i in range(episodes):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    
    current_node = start_node
    path_taken = [current_node]
    episode_reward = 0

    for step in range(15): 
        state_tensor = get_state_tensor(current_node, congestion_state)
        
        # Action Selection (Explore vs Exploit)
        if random.random() < epsilon:
            next_node = random.choice(list(my_graph.neighbors(current_node)))
        else:
            q_values = agent(state_tensor)
            q_vals_numpy = q_values.detach().numpy()[0]
            valid_q_vals = {n: q_vals_numpy[n] for n in my_graph.neighbors(current_node)}
            next_node = max(valid_q_vals, key=valid_q_vals.get)

        # Environment Feedback (Reward)
        if next_node == end_node:
            reward = 100
            done = True
        elif next_node in path_taken:
            reward = -20 # Loop penalty
            done = False
        elif congestion_state[next_node] == 1:
            reward = -30 # Congestion penalty
            done = False
        else:
            reward = -1  # Step penalty
            done = False
            
        next_state_tensor = get_state_tensor(next_node, congestion_state)
        
        # Save to Replay Memory
        memory.append((state_tensor, next_node, reward, next_state_tensor, done))
        
        # Train PyTorch model
        if len(memory) > batch_size:
            batch = random.sample(memory, batch_size)
            optimizer.zero_grad()
            loss = 0
            for s, a, r, n_s, d in batch:
                q_val = agent(s)[0][a] 
                max_next_q = agent(n_s).max() 
                target = r + gamma * max_next_q * (1 - int(d))
                loss += loss_fn(q_val, target.detach()) 
            
            loss = loss / batch_size
            loss.backward()
            optimizer.step()
        
        path_taken.append(next_node)
        current_node = next_node
        episode_reward += reward
        
        if done:
            break
            
    # Track the data over each iteration
    rewards_history.append(episode_reward)
    moving_avg_rewards.append(np.mean(rewards_history[-20:])) 
    epsilon = max(0.01, epsilon * epsilon_decay)

    # ---------------------------------------------------------
    # DASHBOARD: UPDATE GRAPH EVERY 50 ITERATIONS
    # ---------------------------------------------------------
    if (i + 1) % 50 == 0:
        clear_output(wait=True)
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        
        # --- LEFT: Physical Network ---
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, width=1.5, alpha=0.4, edge_color='gray')
        nx.draw_networkx_nodes(my_graph, pos, ax=ax1, node_size=600, node_color=my_colors, edgecolors='black')
        nx.draw_networkx_labels(my_graph, pos, ax=ax1, font_size=10, font_weight='bold')
        
        path_edges = list(zip(path_taken, path_taken[1:]))
        nx.draw_networkx_edges(my_graph, pos, ax=ax1, edgelist=path_edges, width=4, edge_color='blue')
        
        ax1.text(pos[start_node][0], pos[start_node][1]+0.15, s="START", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.text(pos[end_node][0], pos[end_node][1]+0.15, s="DEST", bbox=dict(facecolor='white', alpha=0.7), ha='center')
        ax1.set_title(f"Episode {i+1}/{episodes} | Epsilon: {epsilon:.2f}\nCurrent Path: {path_taken}")
        ax1.axis('off')

        # --- RIGHT: Data Graph Over Each Iteration ---
        ax2.plot(range(1, len(moving_avg_rewards) + 1), moving_avg_rewards, color='purple', linewidth=2.5, label='20-Iteration Moving Avg')
        ax2.scatter(range(1, len(rewards_history) + 1), rewards_history, color='gray', alpha=0.25, s=15, label='Raw Reward per Iteration')
        ax2.set_title("AI Learning Data (Reward vs. Iteration)")
        ax2.set_xlabel("Iteration (Episode)")
        ax2.set_ylabel("Total Reward")
        ax2.grid(True, linestyle='--', alpha=0.6)
        ax2.axhline(y=100, color='green', linestyle='--', label='Target Goal (+100)')
        ax2.legend(loc="lower right")
        
        plt.tight_layout()
        plt.show()

# ==========================================
# 3. FINAL LEARNING CURVE GRAPH
# ==========================================
print("\nTraining Complete! Plotting Final Learning Data...")
time.sleep(1)
clear_output(wait=True)

plt.figure(figsize=(14, 6))
plt.plot(range(1, len(moving_avg_rewards) + 1), moving_avg_rewards, color='purple', linewidth=3, label='20-Iteration Moving Avg')
plt.scatter(range(1, len(rewards_history) + 1), rewards_history, color='gray', alpha=0.3, s=20, label='Raw Reward per Iteration')
plt.title("FINAL OVERALL AI LEARNING DATA\nWatch the Agent Converge to Maximum Efficiency (+100)", fontsize=14, fontweight='bold')
plt.xlabel("Total Iterations (Episodes)", fontsize=12)
plt.ylabel("Reward Score", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.axhline(y=100, color='green', linestyle='--', linewidth=2, label='Target Goal (+100)')
plt.legend(loc="lower right", fontsize=11)
plt.show()



# ==========================================
# 4. DYNAMIC TESTING PHASE
# ==========================================
print("\n=== DYNAMIC ROUTING TEST RESULTS ===")

for test_run in range(3):
    my_colors, congestion_state = congestion_logic(my_graph, start_node, end_node)
    current_node = start_node
    path_taken = [current_node]
    
    # Run fully trained agent (Epsilon = 0)
    for step in range(15):
        state_tensor = get_state_tensor(current_node, congestion_state)
        q_values = agent(state_tensor)
        q_vals_numpy = q_values.detach().numpy()[0]
        valid_q_vals = {n: q_vals_numpy[n] for n in my_graph.neighbors(current_node)}
        next_node = max(valid_q_vals, key=valid_q_vals.get)
        
        path_taken.append(next_node)
        if next_node == end_node:
            break
        current_node = next_node

    # Draw test maps sequentially (Stacked)
    fig, ax1 = plt.subplots(figsize=(8, 5))
    
    nx.draw_networkx_edges(my_graph, pos, ax=ax1, width=1.5, alpha=0.4, edge_color='gray')
    nx.draw_networkx_nodes(my_graph, pos, ax=ax1, node_size=600, node_color=my_colors, edgecolors='black')
    nx.draw_networkx_labels(my_graph, pos, ax=ax1, font_size=10, font_weight='bold')
    
    path_edges = list(zip(path_taken, path_taken[1:]))
    nx.draw_networkx_edges(my_graph, pos, ax=ax1, edgelist=path_edges, width=4, edge_color='blue')
    
    ax1.text(pos[start_node][0], pos[start_node][1]+0.15, s="START", bbox=dict(facecolor='white', alpha=0.8), ha='center')
    ax1.text(pos[end_node][0], pos[end_node][1]+0.15, s="DEST", bbox=dict(facecolor='white', alpha=0.8), ha='center')
    ax1.set_title(f"Dynamic Test {test_run+1}/3 | Path Taken: {path_taken}\nThe AI automatically found the clear route!", fontsize=12)
    ax1.axis('off')
    
    plt.show()
# Out:
# === DYNAMIC ROUTING TEST RESULTS ===
