# %% [raw]
# Creating a Test Network Situation using NetworkX

# %%
pip install networkx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx

G = nx.Graph()
